# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('https://gist.githubusercontent.com/fyyying/4aa5b471860321d7b47fd881898162b7/raw/6907bb3a38bfbb6fccf3a8b1edfb90e39714d14f/titanic_dataset.csv')
test=pd.read_csv('https://gist.githubusercontent.com/aficionado/7743752/raw/c7845b7c4f7bfbebc5681100374248fb71c01cfa/titanic_test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train['Survived'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
train['Age'].value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: Age, Length: 88, dtype: int64

# %%
sns.barplot(x=train['Age'],y=train['Survived'])
plt.xticks(rotation='vertical')
plt.show()

# %%
train.corr()['Survived']
# Out:
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male   NaN
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male   NaN
# 417       3                      Peter, Master. Michael J    male   NaN
#
#      SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
train.drop(columns=['Cabin'],inplace = True)
test.drop(columns=['Cabin'],inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
test.isnull().sum()
# Out:
# Pclass       0
# Name         0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Ticket       0
# Fare         1
# Embarked     0
# dtype: int64

# %%
train['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
train['Embarked'].fillna('S',inplace=True)

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         0
# dtype: int64

# %%
test['Fare'].fillna(test['Fare'].mean(),inplace=True)

# %%
test.isnull().sum()
# Out:
# Pclass       0
# Name         0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Ticket       0
# Fare         0
# Embarked     0
# dtype: int64

# %%
train_age=np.random.randint(train['Age'].mean()-train['Age'].std(),train['Age'].mean()+train['Age'].std(),177)

# %%
train_age
# Out:
# array([25, 19, 27, 24, 40, 22, 29, 36, 30, 15, 26, 24, 43, 27, 38, 19, 41,
#        30, 29, 36, 41, 27, 23, 33, 28, 18, 37, 21, 37, 24, 34, 36, 38, 38,
#        19, 42, 23, 33, 28, 29, 43, 27, 26, 35, 25, 27, 17, 40, 37, 33, 37,
#        35, 29, 19, 19, 42, 35, 17, 33, 27, 33, 30, 18, 19, 20, 27, 42, 21,
#        22, 29, 20, 25, 28, 21, 27, 22, 24, 21, 34, 32, 38, 34, 43, 32, 38,
#        28, 40, 35, 24, 25, 21, 25, 27, 38, 17, 25, 23, 39, 17, 25, 36, 15,
#        20, 20, 43, 23, 21, 43, 27, 18, 33, 32, 36, 27, 29, 43, 26, 31, 34,
#        27, 39, 20, 33, 19, 35, 30, 29, 24, 33, 15, 22, 33, 43, 21, 29, 23,
#        20, 19, 40, 17, 42, 25, 29, 33, 15, 37, 27, 37, 18, 38, 32, 27, 30,
#        26, 39, 24, 15, 36, 35, 42, 41, 24, 17, 34, 20, 20, 18, 24, 34, 23,
#        43, 26, 18, 33, 32, 31, 32])

# %%
test_age=np.random.randint(test['Age'].mean()-test['Age'].std(),test['Age'].mean()+test['Age'].std(),86)

# %%
test_age
# Out:
# array([21, 18, 34, 22, 29, 28, 40, 38, 41, 35, 16, 39, 23, 21, 23, 19, 20,
#        36, 43, 28, 19, 25, 22, 41, 30, 28, 21, 31, 42, 43, 28, 19, 28, 41,
#        31, 32, 33, 35, 25, 34, 19, 41, 35, 35, 32, 17, 37, 38, 27, 42, 19,
#        35, 39, 38, 29, 38, 28, 26, 20, 39, 18, 39, 38, 42, 43, 40, 22, 39,
#        40, 42, 35, 32, 32, 23, 22, 27, 24, 18, 32, 41, 32, 27, 27, 35, 16,
#        29])

# %%
train['Age'][train['Age'].isnull()]=train_age
# Out:
# C:\Users\manab\AppData\Local\Temp\ipykernel_30036\4268069075.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['Age'][train['Age'].isnull()]=train_age

# %%
train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
test['Age'][test['Age'].isnull()]=test_age
# Out:
# C:\Users\manab\AppData\Local\Temp\ipykernel_30036\3484201817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Age'][test['Age'].isnull()]=test_age

# %%
test.isnull().sum()
# Out:
# Pclass      0
# Name        0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# EDA

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.barplot(x=train['Pclass'],y=train['Survived'])
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Survived'>

# %%
train.groupby(['Pclass'])['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
train.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
 train.corr()['Pclass']['Survived']
# Out:
# -0.33848103596101514

# %%
train.groupby(['Embarked'])['Survived'].mean()
# Out:
# Embarked
# C    0.553571
# Q    0.389610
# S    0.339009
# Name: Survived, dtype: float64

# %%
sns.distplot(train ['Age'][train['Survived']==0])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.distplot(train ['Fare'][train['Survived']==0])
sns.distplot(train ['Fare'][train['Survived']==1])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fare', ylabel='Density'>

# %%
train.drop(columns=['Ticket'],inplace=True)
test.drop(columns=['Ticket'],inplace=True)

# %%
train['family']=train['SibSp']+train['Parch']+1
test['family']=test['SibSp']+test['Parch']+1

# %%
train['family'].value_counts()
# Out:
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: family, dtype: int64

# %%
train.groupby(['family'])['Survived'].mean()
# Out:
# family
# 1     0.303538
# 2     0.552795
# 3     0.578431
# 4     0.724138
# 5     0.200000
# 6     0.136364
# 7     0.333333
# 8     0.000000
# 11    0.000000
# Name: Survived, dtype: float64

# %%
def cal(number):
    if number==1:
        return "Alone"
    elif number>1 and number<5:
        return "Medium"
    else:
        return "Large"

# %%
train['family_size']=train['family'].apply(cal)
test['family_size']=test['family'].apply(cal)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
test
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male  35.0
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male  16.0
# 417       3                      Peter, Master. Michael J    male  29.0
#
#      SibSp  Parch      Fare Embarked  family family_size
# ...

# %%
train.drop(columns=['SibSp','Parch','family'],inplace=True)
test.drop(columns=['SibSp','Parch','family'],inplace=True)

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ...

# %%
train.shape
# Out:
# (891, 9)

# %%
test
# Out:
#      Pclass                                          Name     Sex   Age  \
# 0         3                              Kelly, Mr. James    male  34.5
# 1         3              Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2         2                     Myles, Mr. Thomas Francis    male  62.0
# 3         3                              Wirz, Mr. Albert    male  27.0
# 4         3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..      ...                                           ...     ...   ...
# 413       3                            Spector, Mr. Woolf    male  35.0
# 414       1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 415       3                  Saether, Mr. Simon Sivertsen    male  38.5
# 416       3                           Ware, Mr. Frederick    male  16.0
# 417       3                      Peter, Master. Michael J    male  29.0
#
#          Fare Embarked family_size
# 0      7.8292        Q       Alone
# ...

# %%
train.drop(columns=['Name','PassengerId'],inplace=True)
test.drop(columns=['Name'],inplace=True)

# %%
train.isnull().sum()
# Out:
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# Fare           0
# Embarked       0
# family_size    0
# dtype: int64

# %%
test
# Out:
#      Pclass     Sex   Age      Fare Embarked family_size
# 0         3    male  34.5    7.8292        Q       Alone
# 1         3  female  47.0    7.0000        S      Medium
# 2         2    male  62.0    9.6875        Q       Alone
# 3         3    male  27.0    8.6625        S       Alone
# 4         3  female  22.0   12.2875        S      Medium
# ..      ...     ...   ...       ...      ...         ...
# 413       3    male  35.0    8.0500        S       Alone
# 414       1  female  39.0  108.9000        C       Alone
# 415       3    male  38.5    7.2500        S       Alone
# 416       3    male  16.0    8.0500        S       Alone
# 417       3    male  29.0   22.3583        C      Medium
#
# [418 rows x 6 columns]

# %%
train=pd.get_dummies(train,columns=['Pclass','Sex','Embarked','family_size'],drop_first=True)

# %%
train.shape
# Out:
# (891, 10)

# %%
test=pd.get_dummies(test,columns=['Pclass','Sex','Embarked','family_size'],drop_first=True)

# %%
test
# Out:
#       Age      Fare  Pclass_2  Pclass_3  Sex_male  Embarked_Q  Embarked_S  \
# 0    34.5    7.8292         0         1         1           1           0
# 1    47.0    7.0000         0         1         0           0           1
# 2    62.0    9.6875         1         0         1           1           0
# 3    27.0    8.6625         0         1         1           0           1
# 4    22.0   12.2875         0         1         0           0           1
# ..    ...       ...       ...       ...       ...         ...         ...
# 413  35.0    8.0500         0         1         1           0           1
# 414  39.0  108.9000         0         0         0           0           0
# 415  38.5    7.2500         0         1         1           0           1
# 416  16.0    8.0500         0         1         1           0           1
# 417  29.0   22.3583         0         1         1           0           0
#
#      family_size_Large  family_size_Medium
# ...

# %%
test.isnull().sum()
# Out:
# Age                   0
# Fare                  0
# Pclass_2              0
# Pclass_3              0
# Sex_male              0
# Embarked_Q            0
# Embarked_S            0
# family_size_Large     0
# family_size_Medium    0
# dtype: int64

# %%
x=train.iloc[:,1:].values
y=train.iloc[:,0].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
classifier=RandomForestClassifier(n_estimators=10,random_state=0)
#classifier=DecisionTreeClassifier()

# %%
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10, random_state=0)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 0.8100558659217877
