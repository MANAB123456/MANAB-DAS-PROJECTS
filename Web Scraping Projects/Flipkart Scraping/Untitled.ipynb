# %%
import requests
from bs4 import BeautifulSoup

# %%
for i in range(2,10):
    url="https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    soup=BeautifulSoup(r.text,"lxml")
    np=soup.find("a",class_="_1LKTO3").get("href")
    cnp="https://www.flipkart.com"+np
    print (cnp)  # Getting the next page links through thus code
# Out:
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=2
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=3
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=4
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=5
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=6
# https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=7
# ...

# %%
# trying scrapping for the first page
import pandas as pd

Product_Name=[]
Prices=[]
Description=[]

for i in range(2,12):
    url="https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page="+str(i)
    r=requests.get(url)
    soup=BeautifulSoup(r.text,"lxml")
    
    names=soup.find_all("div",class_="_4rR01T")


    for i in names:
        name=i.text
        Product_Name.append(name)
 
    prices=soup.find_all("div",class_="_30jeq3 _1_WHN1")

    for i in prices:
        name=i.text
        Prices.append(name)
        
    desc=soup.find_all("ul",class_="_1xgFaf")

    for i in desc:
        name=i.text
        Description.append(name) 
        
    
df=pd.DataFrame({"Product Name":Product_Name,"Prices":Prices,"Description":Description}) 
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [47], in <cell line: 41>()
#      37     Prices += [price.text for price in prices[:min_length]]
#      38     Description += [description.text for description in desc[:min_length]]
# ---> 41 df=pd.DataFrame({"Product Name":Product_Name,"Prices":Prices,"Description":Description})
#      42 print(df)
#
# File C:\anaconda\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
prices=soup.find_all("div",class_="_30jeq3 _1_WHN1")

for i in prices:
    name=i.text
    Prices.append(name)
print(len(Prices))   

# Display product names and prices
for i in range(len(Product_Name)):
    print(f"Product: {Product_Name[i]}, Price: {Prices[i]}")
# Out:
# 309
# Product: realme X50 Pro 5G (Rust Red, 256 GB), Price: ₹47,999
# Product: MOTOROLA razr 40 (Vanilla Cream, 256 GB), Price: ₹44,999
# Product: Nothing Phone (2a) 5G (Black, 256 GB), Price: ₹27,999
# Product: vivo X90 (Breeze Blue, 256 GB), Price: ₹49,999
# Product: vivo X90 (Asteroid Black, 256 GB), Price: ₹48,500
# Product: OnePlus 9 5G (Astral Black, 256 GB), Price: ₹45,999
# Product: vivo X80 (Cosmic Black, 128 GB), Price: ₹54,999
# Product: Xiaomi 11T Pro 5G Hyperphone (Celestial Magic, 256 GB), Price: ₹49,990
# Product: realme X50 Pro (Moss Green, 256 GB), Price: ₹47,999
# Product: SAMSUNG Galaxy S20 FE 5G (Cloud Navy, 128 GB), Price: ₹26,674
# Product: MOTOROLA Razar 40 (Sage Green, 256 GB), Price: ₹44,999
# Product: IQOO 11 5G (Legend, 256 GB), Price: ₹46,990
# Product: IQOO 11 5G (Alpha, 256 GB), Price: ₹46,990
# Product: OnePlus 9 5G (Arctic Sky, 256 GB), Price: ₹45,990
# Product: Xiaomi 12 Pro 5G (Couture Blue, 256 GB), Price: ₹84,999
# ...

# %%
desc=soup.find_all("ul",class_="_1xgFaf")

for i in desc:
    name=i.text
    Description.append(name)
    
print(len(Description))
# Display product names and prices
for i in range(len(Product_Name)):
    print(f"Product: {Product_Name[i]}, Price: {Prices[i]},desc:{Description[i]}")
# Out:
# 312
# Product: realme X50 Pro 5G (Rust Red, 256 GB), Price: ₹47,999,desc:12 GB RAM | 256 GB ROM16.36 cm (6.44 inch) Full HD+ Display64MP + 12MP + 8MP + 2MP | 32MP + 8MP Dual Front Camera4200 mAh Battery5G PhoneQualcomm Snapdragon 865 Processor65W Superdart ChargeBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories
# Product: MOTOROLA razr 40 (Vanilla Cream, 256 GB), Price: ₹44,999,desc:8 GB RAM | 256 GB ROM17.53 cm (6.9 inch) Display64MP Rear Camera4200 mAh BatteryBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories
# Product: Nothing Phone (2a) 5G (Black, 256 GB), Price: ₹27,999,desc:12 GB RAM | 256 GB ROM17.02 cm (6.7 inch) Full HD+ Display50MP (OIS) + 50MP | 32MP Front Camera5000 mAh BatteryDimensity 7200 Pro Processor1 Year Manufacturing Warranty
# ...

# %%
Product_Name = []
Prices = []
Description = []

for i in range(2, 12):
    url = "https://www.flipkart.com/search?q=mobiles+under+50000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=" + str(i)
    r = requests.get(url)
    soup = BeautifulSoup(r.text, "lxml")

    names = soup.find_all("div", class_="_4rR01T")
    prices = soup.find_all("div", class_="_30jeq3 _1_WHN1")
    desc = soup.find_all("ul", class_="_1xgFaf")

    # Make sure all lists have the same length
    min_length = min(len(names), len(prices), len(desc))

    # Truncate lists to the minimum length
    Product_Name += [name.text for name in names[:min_length]]
    Prices += [price.text for price in prices[:min_length]]
    Description += [description.text for description in desc[:min_length]]

df = pd.DataFrame({"Product Name": Product_Name, "Prices": Prices, "Description": Description})


df.to_csv(r"C:\Users\manab\OneDrive\Desktop\flipkart sss.csv", index=False)
